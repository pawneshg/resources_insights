# %%
mongo_url = "mongodb://consumeRoot:XgMsGkTADzbgM466Y854@myminikube.info:30097"

# %%
import pprint
from pymongo import MongoClient
#mongo_url = 'mongodb://localhost:27017/'
client = MongoClient(mongo_url)
db = client["service-inventory"] # database
inventory = db.service_inventory   # collection
# srv_db = client["service_inventory"]
# srv_coll = srv_db.service_inventory

# %%
match_stage = {"$match": {"provider_code": "aws", "provider_account": {"$in": ["4565435"]}}}
project_stage = {"$project": {"_id":0, "type": 1, "context": 1}}
unwind_stage = {"$unwind": "$context.application"}
#sort_stage = {"$sort": {"context.application": 1}}
groupby_stage = {"$group": {"_id": {"app": "$context.application", "type": "$type"}, "sum": {"$sum": 1}}}
#cosmetic_output = {"$group": {"_id": "$_id.app", "data": {"$push": {"type": "$_id.type", "count": "$sum"}}}}
#rename_id = {"$project": {"_id": 0, "application": "$_id", "data": 1}}

# %%
import time
start_time = time.time()

pprint.pprint(list(db.inventory.aggregate([match_stage, project_stage, unwind_stage, groupby_stage], allowDiskUse=True)))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# [{'_id': {'app': 'cloud_based_app', 'type': 'independent_component'},
#   'sum': 6393},
#  {'_id': {'app': 'ecommerce_app', 'type': 'independent_component'},
#   'sum': 6331},
#  {'_id': {'app': 'cloud_based_app', 'type': 'service_instance'}, 'sum': 22193},
#  {'_id': {'app': 'cam', 'type': 'service_instance'}, 'sum': 21510},
#  {'_id': {'app': 'd2ops', 'type': 'service_instance'}, 'sum': 22384},
#  {'_id': {'app': 'finance_app', 'type': 'independent_component'}, 'sum': 6369},
#  {'_id': {'app': 'aiops', 'type': 'independent_component'}, 'sum': 6303},
#  {'_id': {'app': 'finance_app', 'type': 'service_instance'}, 'sum': 22358},
#  {'_id': {'app': 'd2ops', 'type': 'independent_component'}, 'sum': 6314},
#  {'_id': {'app': 'store', 'type': 'independent_component'}, 'sum': 6276},
#  {'_id': {'app': 'cam', 'type': 'independent_component'}, 'sum': 6368},
#  {'_id': {'app': 'aiops', 'type': 'service_instance'}, 'sum': 22414},
#  {'_id': {'app': 'store', 'type': 'service_instance'}, 'sum': 22721},
#  {'_id': {'app': 'ecommerce_app', 'type': 'service_instance'}, 'sum': 22066}]
# --- 4.9776270389556885 seconds ---

# %% [markdown]
# ## After indexing

# %%
import pymongo

# %%
index_model = pymongo.IndexModel(name="text")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-97e577fdece9> in <module>
# ----> 1 index_model = pymongo.IndexModel(name="text")
#
# TypeError: __init__() missing 1 required positional argument: 'keys'

# %%
indexes = []
text_index = pymongo.IndexModel([("$**", pymongo.TEXT)],
                                name="text_index",
                                background=True)
indexes.append(text_index)

# %%
inventory.create_indexes(indexes)

# %%
inventory.create_indexes([{"name": "text", "description": "text"}])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-bd96f57e6ae9> in <module>
# ----> 1 inventory.create_indexes([{"name": "text", "description": "text"}])
#
# /anaconda2/envs/py36/lib/python3.6/site-packages/pymongo/collection.py in create_indexes(self, indexes, session, **kwargs)
#    1821                     yield document
#    1822             cmd = SON([('createIndexes', self.name),
# -> 1823                        ('indexes', list(gen_indexes()))])
#    1824             cmd.update(kwargs)
#    1825             self._command(
#
# /anaconda2/envs/py36/lib/python3.6/site-packages/pymongo/collection.py in gen_indexes()
#    1812                         raise TypeError(
#    1813                             "%r is not an instance of "
# -> 1814                             "pymongo.operations.IndexModel" % (index,))
#    1815                     document = index.document
#    1816                     if "collation" in document and not supports_collations:
#
# TypeError: {'name': 'text', 'description': 'text'} is not an instance of pymongo.operations.IndexModel

# %%
index_model = pymongo.IndexModel([("provider_code", pymongo.TEXT),
                                                  ("provider_account", pymongo.ASCENDING)],
                                                 name="provider_code_account")

# %%
inventory.create_indexes([index_model])
# Out:
# ['provider_code_account']

# %%
index_model = pymongo.IndexModel([("provider_resource_name", pymongo.DESCENDING)],
                                         name="resource_name_index",
                                         background=True)
srv_coll.create_indexes([index_model])
# Out:
# ['resource_name_index']

# %%
match_stage = {"$match": {"provider_code": "aws", "provider_account": {"$in": ["4565435"]}}}
project_stage = {"$project": {"_id":0, "type": 1, "context": 1}}
unwind_stage = {"$unwind": "$context.application"}
#sort_stage = {"$sort": {"context.application": 1}}
groupby_stage = {"$group": {"_id": {"app": "$context.application", "type": "$type"}, "sum": {"$sum": 1}}}
#cosmetic_output = {"$group": {"_id": "$_id.app", "data": {"$push": {"type": "$_id.type", "count": "$sum"}}}}
#rename_id = {"$project": {"_id": 0, "application": "$_id", "data": 1}}

# %%
import time
start_time = time.time()

pprint.pprint(list(db.inventory.aggregate([match_stage, project_stage, unwind_stage, groupby_stage], allowDiskUse=True)))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# [{'_id': {'app': 'cloud_based_app', 'type': 'independent_component'},
#   'sum': 6393},
#  {'_id': {'app': 'ecommerce_app', 'type': 'independent_component'},
#   'sum': 6331},
#  {'_id': {'app': 'cloud_based_app', 'type': 'service_instance'}, 'sum': 22193},
#  {'_id': {'app': 'cam', 'type': 'service_instance'}, 'sum': 21510},
#  {'_id': {'app': 'd2ops', 'type': 'service_instance'}, 'sum': 22384},
#  {'_id': {'app': 'finance_app', 'type': 'independent_component'}, 'sum': 6369},
#  {'_id': {'app': 'aiops', 'type': 'independent_component'}, 'sum': 6303},
#  {'_id': {'app': 'finance_app', 'type': 'service_instance'}, 'sum': 22358},
#  {'_id': {'app': 'd2ops', 'type': 'independent_component'}, 'sum': 6314},
#  {'_id': {'app': 'store', 'type': 'independent_component'}, 'sum': 6276},
#  {'_id': {'app': 'cam', 'type': 'independent_component'}, 'sum': 6368},
#  {'_id': {'app': 'aiops', 'type': 'service_instance'}, 'sum': 22414},
#  {'_id': {'app': 'store', 'type': 'service_instance'}, 'sum': 22721},
#  {'_id': {'app': 'ecommerce_app', 'type': 'service_instance'}, 'sum': 22066}]
# --- 2.715181827545166 seconds ---

# %%
###Improving

# %%
match_stage = {"$match": {"provider_code": "aws", "provider_account": "4565435"}}
application_match_stage = {"$match": {"context.application": {"$in": ['ecommerce_app', 'finance_app', 'store', 'aiops', 'd2ops', 'cam', 'cloud_based_app']}}}
project_stage = {"$project": {"_id":0, "type": 1, "context": 1}}
unwind_stage = {"$unwind": "$context.application"}
#sort_stage = {"$sort": {"context.application": 1}}
groupby_stage = {"$group": {"_id": {"app": "$context.application", "type": "$type"}, "sum": {"$sum": 1}}}
#cosmetic_output = {"$group": {"_id": "$_id.app", "data": {"$push": {"type": "$_id.type", "count": "$sum"}}}}
#rename_id = {"$project": {"_id": 0, "application": "$_id", "data": 1}}

# %%
import time
start_time = time.time()

pprint.pprint(list(db.inventory.aggregate([match_stage, application_match_stage, project_stage, unwind_stage, groupby_stage], allowDiskUse=True)))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# [{'_id': {'app': 'cloud_based_app', 'type': 'independent_component'},
#   'sum': 6393},
#  {'_id': {'app': 'ecommerce_app', 'type': 'independent_component'},
#   'sum': 6331},
#  {'_id': {'app': 'cloud_based_app', 'type': 'service_instance'}, 'sum': 22193},
#  {'_id': {'app': 'cam', 'type': 'service_instance'}, 'sum': 21510},
#  {'_id': {'app': 'd2ops', 'type': 'service_instance'}, 'sum': 22384},
#  {'_id': {'app': 'finance_app', 'type': 'independent_component'}, 'sum': 6369},
#  {'_id': {'app': 'aiops', 'type': 'independent_component'}, 'sum': 6303},
#  {'_id': {'app': 'finance_app', 'type': 'service_instance'}, 'sum': 22358},
#  {'_id': {'app': 'd2ops', 'type': 'independent_component'}, 'sum': 6314},
#  {'_id': {'app': 'store', 'type': 'independent_component'}, 'sum': 6276},
#  {'_id': {'app': 'cam', 'type': 'independent_component'}, 'sum': 6368},
#  {'_id': {'app': 'aiops', 'type': 'service_instance'}, 'sum': 22414},
#  {'_id': {'app': 'store', 'type': 'service_instance'}, 'sum': 22721},
#  {'_id': {'app': 'ecommerce_app', 'type': 'service_instance'}, 'sum': 22066}]
# --- 3.0396318435668945 seconds ---

# %% [markdown]
# ## On 1 million without any match filter

# %%
match_stage = {"$match": {"providerName": "1Million_data_24june", "assetAccountId": "1Million_data_24june_ba0_aa0"}}
application_match_stage = {"$match": {"context.application": {"$in": ['app1', 'app2', 'app3', 'app4', 'app5', 'app7', 'app8']}}}
project_stage = {"$project": {"_id":0, "type": 1, "context": 1}}
unwind_stage = {"$unwind": "$context.application"}
#sort_stage = {"$sort": {"context.application": 1}}
limit_stage = {"$limit": 50}
groupby_stage = {"$group": {"_id": {"app": "$context.application", "type": "$type"}, "sum": {"$sum": 1}}}
#cosmetic_output = {"$group": {"_id": "$_id.app", "data": {"$push": {"type": "$_id.type", "count": "$sum"}}}}
#rename_id = {"$project": {"_id": 0, "application": "$_id", "data": 1}}

# %%
import time, pprint
start_time = time.time()

pprint.pprint(list(inventory.aggregate([match_stage, application_match_stage, limit_stage], allowDiskUse=True)))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# [{'_id': ObjectId('5d1313cbf67cd43a0cab6afa'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '4932mumbaiCache',
#   'assetParentId': '',
#   'assetType': 'Cache',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app4'],
#               'environment': ['env2'],
#               'organisation': ['org3'],
#               'team': ['team2']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.176',
#   'description': 'Cache mumbai 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.486',
#   'invoiceEndDate': '2019-01-08 01:30:00.462',
#   'invoiceStartDate': '2019-01-02 01:30:00.903',
#   'orderId': '',
#   'pcCustomerTotalCost': '37',
#   'pcCustomerUnitCost': '30',
#   'pcProviderTaxCost': '98',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '30',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_0',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '0',
#   'providerInvoiceId': '12',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1452019',
#   'providerRegion': 'mumbai',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-16 01:30:00.514',
#   'serviceStartDate': '2019-01-09 01:30:00.837',
#   'tags': [{'iCloud_55': 'tagValue_55'},
#            {'iCloud_7': 'tagValue_7'},
#            {'iCloud_82': 'tagValue_82'},
#            {'iCloud_72': 'tagValue_72'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6afc'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '6072CentralUSMicrosoft.Compute/disks',
#   'assetParentId': '',
#   'assetType': 'Microsoft.Compute/disks',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app8'],
#               'environment': ['env4'],
#               'organisation': ['org4'],
#               'team': ['team2']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.167',
#   'description': 'Microsoft.Compute/disks CentralUS 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.169',
#   'invoiceEndDate': '2019-01-08 01:30:00.629',
#   'invoiceStartDate': '2019-01-02 01:30:00.968',
#   'orderId': '',
#   'pcCustomerTotalCost': '76',
#   'pcCustomerUnitCost': '20',
#   'pcProviderTaxCost': '19',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '20',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_1',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '0',
#   'providerInvoiceId': '111',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1262019',
#   'providerRegion': 'CentralUS',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-15 01:30:00.454',
#   'serviceStartDate': '2019-01-09 01:30:00.904',
#   'tags': [{'iCloud_21': 'tagValue_21'},
#            {'iCloud_28': 'tagValue_28'},
#            {'iCloud_62': 'tagValue_62'},
#            {'iCloud_73': 'tagValue_73'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6afd'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '1338us-gov-west-1networkInterfaces',
#   'assetParentId': '',
#   'assetType': 'networkInterfaces',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app7'],
#               'environment': ['env20'],
#               'organisation': ['org2'],
#               'team': ['team1']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.658',
#   'description': 'networkInterfaces us-gov-west-1 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.976',
#   'invoiceEndDate': '2019-01-08 01:30:00.434',
#   'invoiceStartDate': '2019-01-02 01:30:00.822',
#   'orderId': '',
#   'pcCustomerTotalCost': '92',
#   'pcCustomerUnitCost': '56',
#   'pcProviderTaxCost': '66',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '56',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_1',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '1',
#   'providerInvoiceId': '53',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1222019',
#   'providerRegion': 'us-gov-west-1',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-17 01:30:00.855',
#   'serviceStartDate': '2019-01-09 01:30:00.983',
#   'tags': [{'iCloud_21': 'tagValue_21'},
#            {'iCloud_28': 'tagValue_28'},
#            {'iCloud_62': 'tagValue_62'},
#            {'iCloud_73': 'tagValue_73'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b01'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '8873southamerica-east1-cMicrosoft.Compute/disks',
#   'assetParentId': '',
#   'assetType': 'Microsoft.Compute/disks',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app2'],
#               'environment': ['env12'],
#               'organisation': ['org3'],
#               'team': ['team4']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.905',
#   'description': 'Microsoft.Compute/disks southamerica-east1-c '
#                  '1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.973',
#   'invoiceEndDate': '2019-01-08 01:30:00.801',
#   'invoiceStartDate': '2019-01-02 01:30:00.187',
#   'orderId': '',
#   'pcCustomerTotalCost': '18',
#   'pcCustomerUnitCost': '13',
#   'pcProviderTaxCost': '8',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '13',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_2',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '0',
#   'providerInvoiceId': '47',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1802019',
#   'providerRegion': 'southamerica-east1-c',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-20 01:30:00.964',
#   'serviceStartDate': '2019-01-09 01:30:00.782',
#   'tags': [{'iCloud_82': 'tagValue_82'},
#            {'iCloud_44': 'tagValue_44'},
#            {'iCloud_6': 'tagValue_6'},
#            {'iCloud_46': 'tagValue_46'},
#            {'iCloud_54': 'tagValue_54'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b07'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '7210germanycentralBatch',
#   'assetParentId': '',
#   'assetType': 'Batch',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app3'],
#               'environment': ['env8'],
#               'organisation': ['org3'],
#               'team': ['team5']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.446',
#   'description': 'Batch germanycentral 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.635',
#   'invoiceEndDate': '2019-01-08 01:30:00.350',
#   'invoiceStartDate': '2019-01-02 01:30:00.191',
#   'orderId': '',
#   'pcCustomerTotalCost': '43',
#   'pcCustomerUnitCost': '73',
#   'pcProviderTaxCost': '81',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '73',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_3',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '1',
#   'providerInvoiceId': '110',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1372019',
#   'providerRegion': 'germanycentral',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-13 01:30:00.929',
#   'serviceStartDate': '2019-01-09 01:30:00.987',
#   'tags': [{'iCloud_43': 'tagValue_43'},
#            {'iCloud_19': 'tagValue_19'},
#            {'iCloud_61': 'tagValue_61'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b08'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '2575ausoutheastData Management',
#   'assetParentId': '',
#   'assetType': 'Data Management',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app2'],
#               'environment': ['env15'],
#               'organisation': ['org1'],
#               'team': ['team5']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.453',
#   'description': 'Data Management ausoutheast 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.589',
#   'invoiceEndDate': '2019-01-08 01:30:00.728',
#   'invoiceStartDate': '2019-01-02 01:30:00.836',
#   'orderId': '',
#   'pcCustomerTotalCost': '78',
#   'pcCustomerUnitCost': '64',
#   'pcProviderTaxCost': '54',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '64',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_3',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '1',
#   'providerInvoiceId': '11',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1572019',
#   'providerRegion': 'ausoutheast',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-15 01:30:00.360',
#   'serviceStartDate': '2019-01-09 01:30:00.411',
#   'tags': [{'iCloud_43': 'tagValue_43'},
#            {'iCloud_19': 'tagValue_19'},
#            {'iCloud_61': 'tagValue_61'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b09'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '4401puneNetworking',
#   'assetParentId': '',
#   'assetType': 'Networking',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app4'],
#               'environment': ['env11'],
#               'organisation': ['org2'],
#               'team': ['team1']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.439',
#   'description': 'Networking pune 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.686',
#   'invoiceEndDate': '2019-01-08 01:30:00.434',
#   'invoiceStartDate': '2019-01-02 01:30:00.402',
#   'orderId': '',
#   'pcCustomerTotalCost': '44',
#   'pcCustomerUnitCost': '52',
#   'pcProviderTaxCost': '2',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '52',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_3',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '1',
#   'providerInvoiceId': '106',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1772019',
#   'providerRegion': 'pune',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-26 01:30:00.538',
#   'serviceStartDate': '2019-01-09 01:30:00.319',
#   'tags': [{'iCloud_43': 'tagValue_43'},
#            {'iCloud_19': 'tagValue_19'},
#            {'iCloud_61': 'tagValue_61'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b11'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '4228masData Management',
#   'assetParentId': '',
#   'assetType': 'Data Management',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app3'],
#               'environment': ['env10'],
#               'organisation': ['org2'],
#               'team': ['team5']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.379',
#   'description': 'Data Management mas 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.414',
#   'invoiceEndDate': '2019-01-08 01:30:00.446',
#   'invoiceStartDate': '2019-01-02 01:30:00.937',
#   'orderId': '',
#   'pcCustomerTotalCost': '72',
#   'pcCustomerUnitCost': '24',
#   'pcProviderTaxCost': '16',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '24',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_5',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '1',
#   'providerInvoiceId': '22',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1602019',
#   'providerRegion': 'mas',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-12 01:30:00.683',
#   'serviceStartDate': '2019-01-09 01:30:00.803',
#   'tags': [{'iCloud_60': 'tagValue_60'}, {'iCloud_18': 'tagValue_18'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b12'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '6534dallasVirtual Network',
#   'assetParentId': '',
#   'assetType': 'Virtual Network',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app4'],
#               'environment': ['env11'],
#               'organisation': ['org5'],
#               'team': ['team5']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.627',
#   'description': 'Virtual Network dallas 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.755',
#   'invoiceEndDate': '2019-01-08 01:30:00.772',
#   'invoiceStartDate': '2019-01-02 01:30:00.528',
#   'orderId': '',
#   'pcCustomerTotalCost': '43',
#   'pcCustomerUnitCost': '23',
#   'pcProviderTaxCost': '46',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '23',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_5',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '1',
#   'providerInvoiceId': '17',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '2002019',
#   'providerRegion': 'dallas',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-10 01:30:00.746',
#   'serviceStartDate': '2019-01-09 01:30:00.728',
#   'tags': [{'iCloud_60': 'tagValue_60'}, {'iCloud_18': 'tagValue_18'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b14'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '8574dallasData Services',
#   'assetParentId': '',
#   'assetType': 'Data Services',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app2'],
#               'environment': ['env18'],
#               'organisation': ['org3'],
#               'team': ['team4']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.592',
#   'description': 'Data Services dallas 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.491',
#   'invoiceEndDate': '2019-01-08 01:30:00.187',
#   'invoiceStartDate': '2019-01-02 01:30:00.413',
#   'orderId': '',
#   'pcCustomerTotalCost': '61',
#   'pcCustomerUnitCost': '50',
#   'pcProviderTaxCost': '70',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '50',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_6',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '1',
#   'providerInvoiceId': '15',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1912019',
#   'providerRegion': 'dallas',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-30 01:30:00.303',
#   'serviceStartDate': '2019-01-09 01:30:00.648',
#   'tags': [{'iCloud_87': 'tagValue_87'}, {'iCloud_40': 'tagValue_40'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b15'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '1696apsoutheastBatch',
#   'assetParentId': '',
#   'assetType': 'Batch',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app4'],
#               'environment': ['env18'],
#               'organisation': ['org5'],
#               'team': ['team2']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.731',
#   'description': 'Batch apsoutheast 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.289',
#   'invoiceEndDate': '2019-01-08 01:30:00.653',
#   'invoiceStartDate': '2019-01-02 01:30:00.510',
#   'orderId': '',
#   'pcCustomerTotalCost': '29',
#   'pcCustomerUnitCost': '38',
#   'pcProviderTaxCost': '53',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '38',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_6',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '0',
#   'providerInvoiceId': '100',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1502019',
#   'providerRegion': 'apsoutheast',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-18 01:30:00.868',
#   'serviceStartDate': '2019-01-09 01:30:00.463',
#   'tags': [{'iCloud_87': 'tagValue_87'}, {'iCloud_40': 'tagValue_40'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b16'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '7173southamerica-east1-cAPI Management',
#   'assetParentId': '',
#   'assetType': 'API Management',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app8'],
#               'environment': ['env19'],
#               'organisation': ['org1'],
#               'team': ['team2']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.317',
#   'description': 'API Management southamerica-east1-c 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.147',
#   'invoiceEndDate': '2019-01-08 01:30:00.387',
#   'invoiceStartDate': '2019-01-02 01:30:00.338',
#   'orderId': '',
#   'pcCustomerTotalCost': '43',
#   'pcCustomerUnitCost': '37',
#   'pcProviderTaxCost': '46',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '37',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_6',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '1',
#   'providerInvoiceId': '55',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1782019',
#   'providerRegion': 'southamerica-east1-c',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-27 01:30:00.958',
#   'serviceStartDate': '2019-01-09 01:30:00.363',
#   'tags': [{'iCloud_87': 'tagValue_87'}, {'iCloud_40': 'tagValue_40'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b1b'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '9015Central USDatastore',
#   'assetParentId': '',
#   'assetType': 'Datastore',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app1'],
#               'environment': ['env13'],
#               'organisation': ['org4'],
#               'team': ['team2']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.167',
#   'description': 'Datastore Central US 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.702',
#   'invoiceEndDate': '2019-01-08 01:30:00.317',
#   'invoiceStartDate': '2019-01-02 01:30:00.719',
#   'orderId': '',
#   'pcCustomerTotalCost': '1',
#   'pcCustomerUnitCost': '74',
#   'pcProviderTaxCost': '13',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '74',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_7',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '1',
#   'providerInvoiceId': '107',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1772019',
#   'providerRegion': 'Central US',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-11 01:30:00.135',
#   'serviceStartDate': '2019-01-09 01:30:00.230',
#   'tags': [{'iCloud_95': 'tagValue_95'}, {'iCloud_3': 'tagValue_3'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b1c'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '6932calfData Management',
#   'assetParentId': '',
#   'assetType': 'Data Management',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app4'],
#               'environment': ['env20'],
#               'organisation': ['org4'],
#               'team': ['team1']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.229',
#   'description': 'Data Management calf 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.782',
#   'invoiceEndDate': '2019-01-08 01:30:00.969',
#   'invoiceStartDate': '2019-01-02 01:30:00.538',
#   'orderId': '',
#   'pcCustomerTotalCost': '17',
#   'pcCustomerUnitCost': '5',
#   'pcProviderTaxCost': '42',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '5',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_7',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '0',
#   'providerInvoiceId': '115',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1232019',
#   'providerRegion': 'calf',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-21 01:30:00.242',
#   'serviceStartDate': '2019-01-09 01:30:00.881',
#   'tags': [{'iCloud_95': 'tagValue_95'}, {'iCloud_3': 'tagValue_3'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b22'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '8063calfStorage',
#   'assetParentId': '',
#   'assetType': 'Storage',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app2'],
#               'environment': ['env13'],
#               'organisation': ['org5'],
#               'team': ['team1']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.145',
#   'description': 'Storage calf 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.503',
#   'invoiceEndDate': '2019-01-08 01:30:00.891',
#   'invoiceStartDate': '2019-01-02 01:30:00.249',
#   'orderId': '',
#   'pcCustomerTotalCost': '71',
#   'pcCustomerUnitCost': '8',
#   'pcProviderTaxCost': '35',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '8',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_8',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '0',
#   'providerInvoiceId': '57',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1852019',
#   'providerRegion': 'calf',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-14 01:30:00.518',
#   'serviceStartDate': '2019-01-09 01:30:00.528',
#   'tags': [{'iCloud_82': 'tagValue_82'},
#            {'iCloud_8': 'tagValue_8'},
#            {'iCloud_9': 'tagValue_9'},
#            {'iCloud_44': 'tagValue_44'},
#            {'iCloud_66': 'tagValue_66'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b28'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '6979australiaeastData Services',
#   'assetParentId': '',
#   'assetType': 'Data Services',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app2'],
#               'environment': ['env17'],
#               'organisation': ['org1'],
#               'team': ['team1']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.484',
#   'description': 'Data Services australiaeast 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.492',
#   'invoiceEndDate': '2019-01-08 01:30:00.645',
#   'invoiceStartDate': '2019-01-02 01:30:00.962',
#   'orderId': '',
#   'pcCustomerTotalCost': '12',
#   'pcCustomerUnitCost': '94',
#   'pcProviderTaxCost': '1',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '94',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_10',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '0',
#   'providerInvoiceId': '111',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1672019',
#   'providerRegion': 'australiaeast',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-17 01:30:00.839',
#   'serviceStartDate': '2019-01-09 01:30:00.404',
#   'tags': [{'iCloud_83': 'tagValue_83'},
#            {'iCloud_21': 'tagValue_21'},
#            {'iCloud_40': 'tagValue_40'},
#            {'iCloud_57': 'tagValue_57'},
#            {'iCloud_6': 'tagValue_6'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b2a'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '4689brazilsouthNetworking',
#   'assetParentId': '',
#   'assetType': 'Networking',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app8'],
#               'environment': ['env3'],
#               'organisation': ['org2'],
#               'team': ['team3']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.297',
#   'description': 'Networking brazilsouth 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.936',
#   'invoiceEndDate': '2019-01-08 01:30:00.262',
#   'invoiceStartDate': '2019-01-02 01:30:00.228',
#   'orderId': '',
#   'pcCustomerTotalCost': '69',
#   'pcCustomerUnitCost': '88',
#   'pcProviderTaxCost': '26',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '88',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_10',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '1',
#   'providerInvoiceId': '7',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1782019',
#   'providerRegion': 'brazilsouth',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-28 01:30:00.857',
#   'serviceStartDate': '2019-01-09 01:30:00.979',
#   'tags': [{'iCloud_83': 'tagValue_83'},
#            {'iCloud_21': 'tagValue_21'},
#            {'iCloud_40': 'tagValue_40'},
#            {'iCloud_57': 'tagValue_57'},
#            {'iCloud_6': 'tagValue_6'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b2b'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '6907germanycentralData Services',
#   'assetParentId': '',
#   'assetType': 'Data Services',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app2'],
#               'environment': ['env12'],
#               'organisation': ['org1'],
#               'team': ['team2']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.653',
#   'description': 'Data Services germanycentral 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.647',
#   'invoiceEndDate': '2019-01-08 01:30:00.750',
#   'invoiceStartDate': '2019-01-02 01:30:00.224',
#   'orderId': '',
#   'pcCustomerTotalCost': '59',
#   'pcCustomerUnitCost': '32',
#   'pcProviderTaxCost': '94',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '32',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_10',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '1',
#   'providerInvoiceId': '92',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1872019',
#   'providerRegion': 'germanycentral',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-25 01:30:00.240',
#   'serviceStartDate': '2019-01-09 01:30:00.455',
#   'tags': [{'iCloud_83': 'tagValue_83'},
#            {'iCloud_21': 'tagValue_21'},
#            {'iCloud_40': 'tagValue_40'},
#            {'iCloud_57': 'tagValue_57'},
#            {'iCloud_6': 'tagValue_6'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b2c'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '6128us-gov-west-1Data Services',
#   'assetParentId': '',
#   'assetType': 'Data Services',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app5'],
#               'environment': ['env10'],
#               'organisation': ['org5'],
#               'team': ['team4']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.168',
#   'description': 'Data Services us-gov-west-1 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.249',
#   'invoiceEndDate': '2019-01-08 01:30:00.775',
#   'invoiceStartDate': '2019-01-02 01:30:00.530',
#   'orderId': '',
#   'pcCustomerTotalCost': '58',
#   'pcCustomerUnitCost': '38',
#   'pcProviderTaxCost': '95',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '38',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_10',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '1',
#   'providerInvoiceId': '93',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1522019',
#   'providerRegion': 'us-gov-west-1',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-30 01:30:00.635',
#   'serviceStartDate': '2019-01-09 01:30:00.655',
#   'tags': [{'iCloud_83': 'tagValue_83'},
#            {'iCloud_21': 'tagValue_21'},
#            {'iCloud_40': 'tagValue_40'},
#            {'iCloud_57': 'tagValue_57'},
#            {'iCloud_6': 'tagValue_6'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b2d'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '603germanycentralNetworking',
#   'assetParentId': '',
#   'assetType': 'Networking',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app4'],
#               'environment': ['env9'],
#               'organisation': ['org1'],
#               'team': ['team3']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.158',
#   'description': 'Networking germanycentral 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.170',
#   'invoiceEndDate': '2019-01-08 01:30:00.913',
#   'invoiceStartDate': '2019-01-02 01:30:00.460',
#   'orderId': '',
#   'pcCustomerTotalCost': '67',
#   'pcCustomerUnitCost': '34',
#   'pcProviderTaxCost': '77',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '34',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_11',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '1',
#   'providerInvoiceId': '38',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1942019',
#   'providerRegion': 'germanycentral',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-19 01:30:00.469',
#   'serviceStartDate': '2019-01-09 01:30:00.675',
#   'tags': [{'iCloud_88': 'tagValue_88'}, {'iCloud_83': 'tagValue_83'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b32'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '623germanycentralVirtual Network',
#   'assetParentId': '',
#   'assetType': 'Virtual Network',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app8'],
#               'environment': ['env7'],
#               'organisation': ['org1'],
#               'team': ['team4']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.906',
#   'description': 'Virtual Network germanycentral 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.815',
#   'invoiceEndDate': '2019-01-08 01:30:00.417',
#   'invoiceStartDate': '2019-01-02 01:30:00.921',
#   'orderId': '',
#   'pcCustomerTotalCost': '38',
#   'pcCustomerUnitCost': '11',
#   'pcProviderTaxCost': '65',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '11',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_12',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '1',
#   'providerInvoiceId': '50',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1602019',
#   'providerRegion': 'germanycentral',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-18 01:30:00.900',
#   'serviceStartDate': '2019-01-09 01:30:00.567',
#   'tags': [{'iCloud_12': 'tagValue_12'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b33'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '5026puneVirtual Network',
#   'assetParentId': '',
#   'assetType': 'Virtual Network',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app1'],
#               'environment': ['env8'],
#               'organisation': ['org2'],
#               'team': ['team1']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.768',
#   'description': 'Virtual Network pune 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.637',
#   'invoiceEndDate': '2019-01-08 01:30:00.452',
#   'invoiceStartDate': '2019-01-02 01:30:00.472',
#   'orderId': '',
#   'pcCustomerTotalCost': '82',
#   'pcCustomerUnitCost': '79',
#   'pcProviderTaxCost': '67',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '79',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_12',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '0',
#   'providerInvoiceId': '25',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1362019',
#   'providerRegion': 'pune',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-18 01:30:00.775',
#   'serviceStartDate': '2019-01-09 01:30:00.825',
#   'tags': [{'iCloud_12': 'tagValue_12'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b35'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '7486asia-east1Storage',
#   'assetParentId': '',
#   'assetType': 'Storage',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app5'],
#               'environment': ['env6'],
#               'organisation': ['org1'],
#               'team': ['team2']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.154',
#   'description': 'Storage asia-east1 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.191',
#   'invoiceEndDate': '2019-01-08 01:30:00.936',
#   'invoiceStartDate': '2019-01-02 01:30:00.177',
#   'orderId': '',
#   'pcCustomerTotalCost': '89',
#   'pcCustomerUnitCost': '95',
#   'pcProviderTaxCost': '68',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '95',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_12',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '0',
#   'providerInvoiceId': '72',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1822019',
#   'providerRegion': 'asia-east1',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-11 01:30:00.623',
#   'serviceStartDate': '2019-01-09 01:30:00.627',
#   'tags': [{'iCloud_12': 'tagValue_12'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b36'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '2797Storage',
#   'assetParentId': '',
#   'assetType': 'Storage',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app4'],
#               'environment': ['env10'],
#               'organisation': ['org3'],
#               'team': ['team1']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.597',
#   'description': 'Storage  1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.654',
#   'invoiceEndDate': '2019-01-08 01:30:00.603',
#   'invoiceStartDate': '2019-01-02 01:30:00.901',
#   'orderId': '',
#   'pcCustomerTotalCost': '67',
#   'pcCustomerUnitCost': '15',
#   'pcProviderTaxCost': '94',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '15',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_12',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '0',
#   'providerInvoiceId': '91',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1942019',
#   'providerRegion': '',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-12 01:30:00.754',
#   'serviceStartDate': '2019-01-09 01:30:00.681',
#   'tags': [{'iCloud_12': 'tagValue_12'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b38'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '1709puneVirtualMachine',
#   'assetParentId': '',
#   'assetType': 'VirtualMachine',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app4'],
#               'environment': ['env15'],
#               'organisation': ['org4'],
#               'team': ['team5']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.479',
#   'description': 'VirtualMachine pune 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.242',
#   'invoiceEndDate': '2019-01-08 01:30:00.154',
#   'invoiceStartDate': '2019-01-02 01:30:00.534',
#   'orderId': '',
#   'pcCustomerTotalCost': '50',
#   'pcCustomerUnitCost': '61',
#   'pcProviderTaxCost': '95',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '61',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_13',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '0',
#   'providerInvoiceId': '2',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1722019',
#   'providerRegion': 'pune',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-13 01:30:00.947',
#   'serviceStartDate': '2019-01-09 01:30:00.553',
#   'tags': [{'iCloud_74': 'tagValue_74'},
#            {'iCloud_22': 'tagValue_22'},
#            {'iCloud_73': 'tagValue_73'},
#            {'iCloud_25': 'tagValue_25'},
#            {'iCloud_83': 'tagValue_83'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b39'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '1255aueastStorage',
#   'assetParentId': '',
#   'assetType': 'Storage',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app5'],
#               'environment': ['env8'],
#               'organisation': ['org3'],
#               'team': ['team1']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.180',
#   'description': 'Storage aueast 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.712',
#   'invoiceEndDate': '2019-01-08 01:30:00.948',
#   'invoiceStartDate': '2019-01-02 01:30:00.786',
#   'orderId': '',
#   'pcCustomerTotalCost': '49',
#   'pcCustomerUnitCost': '38',
#   'pcProviderTaxCost': '50',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '38',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_13',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '0',
#   'providerInvoiceId': '60',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1532019',
#   'providerRegion': 'aueast',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-10 01:30:00.470',
#   'serviceStartDate': '2019-01-09 01:30:00.924',
#   'tags': [{'iCloud_74': 'tagValue_74'},
#            {'iCloud_22': 'tagValue_22'},
#            {'iCloud_73': 'tagValue_73'},
#            {'iCloud_25': 'tagValue_25'},
#            {'iCloud_83': 'tagValue_83'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b3a'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '7424asia-east1Automation',
#   'assetParentId': '',
#   'assetType': 'Automation',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app1'],
#               'environment': ['env3'],
#               'organisation': ['org3'],
#               'team': ['team2']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.498',
#   'description': 'Automation asia-east1 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.220',
#   'invoiceEndDate': '2019-01-08 01:30:00.422',
#   'invoiceStartDate': '2019-01-02 01:30:00.169',
#   'orderId': '',
#   'pcCustomerTotalCost': '83',
#   'pcCustomerUnitCost': '73',
#   'pcProviderTaxCost': '12',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '73',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_13',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '1',
#   'providerInvoiceId': '87',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1852019',
#   'providerRegion': 'asia-east1',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-29 01:30:00.571',
#   'serviceStartDate': '2019-01-09 01:30:00.301',
#   'tags': [{'iCloud_74': 'tagValue_74'},
#            {'iCloud_22': 'tagValue_22'},
#            {'iCloud_73': 'tagValue_73'},
#            {'iCloud_25': 'tagValue_25'},
#            {'iCloud_83': 'tagValue_83'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b3b'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '7227ausoutheastNetworking',
#   'assetParentId': '',
#   'assetType': 'Networking',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app5'],
#               'environment': ['env12'],
#               'organisation': ['org2'],
#               'team': ['team3']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.801',
#   'description': 'Networking ausoutheast 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.933',
#   'invoiceEndDate': '2019-01-08 01:30:00.194',
#   'invoiceStartDate': '2019-01-02 01:30:00.513',
#   'orderId': '',
#   'pcCustomerTotalCost': '20',
#   'pcCustomerUnitCost': '29',
#   'pcProviderTaxCost': '15',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '29',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_13',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '0',
#   'providerInvoiceId': '105',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1202019',
#   'providerRegion': 'ausoutheast',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-11 01:30:00.753',
#   'serviceStartDate': '2019-01-09 01:30:00.856',
#   'tags': [{'iCloud_74': 'tagValue_74'},
#            {'iCloud_22': 'tagValue_22'},
#            {'iCloud_73': 'tagValue_73'},
#            {'iCloud_25': 'tagValue_25'},
#            {'iCloud_83': 'tagValue_83'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b3d'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '4380puneAutomation and Control',
#   'assetParentId': '',
#   'assetType': 'Automation and Control',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app3'],
#               'environment': ['env20'],
#               'organisation': ['org1'],
#               'team': ['team2']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.863',
#   'description': 'Automation and Control pune 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.536',
#   'invoiceEndDate': '2019-01-08 01:30:00.389',
#   'invoiceStartDate': '2019-01-02 01:30:00.864',
#   'orderId': '',
#   'pcCustomerTotalCost': '71',
#   'pcCustomerUnitCost': '97',
#   'pcProviderTaxCost': '4',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '97',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_14',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '1',
#   'providerInvoiceId': '102',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1522019',
#   'providerRegion': 'pune',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-18 01:30:00.698',
#   'serviceStartDate': '2019-01-09 01:30:00.825',
#   'tags': [{'iCloud_79': 'tagValue_79'},
#            {'iCloud_74': 'tagValue_74'},
#            {'iCloud_51': 'tagValue_51'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b41'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '3569asia-east1Data Management',
#   'assetParentId': '',
#   'assetType': 'Data Management',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app4'],
#               'environment': ['env4'],
#               'organisation': ['org5'],
#               'team': ['team5']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.627',
#   'description': 'Data Management asia-east1 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.931',
#   'invoiceEndDate': '2019-01-08 01:30:00.241',
#   'invoiceStartDate': '2019-01-02 01:30:00.184',
#   'orderId': '',
#   'pcCustomerTotalCost': '37',
#   'pcCustomerUnitCost': '54',
#   'pcProviderTaxCost': '35',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '54',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_15',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '1',
#   'providerInvoiceId': '51',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1612019',
#   'providerRegion': 'asia-east1',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-19 01:30:00.390',
#   'serviceStartDate': '2019-01-09 01:30:00.548',
#   'tags': [{'iCloud_36': 'tagValue_36'},
#            {'iCloud_89': 'tagValue_89'},
#            {'iCloud_36': 'tagValue_36'},
#            {'iCloud_23': 'tagValue_23'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b44'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '6952eastusVirtualMachine',
#   'assetParentId': '',
#   'assetType': 'VirtualMachine',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app4'],
#               'environment': ['env3'],
# ...
#   'assetParentId': '',
#   'assetType': 'API Management',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app3'],
#               'environment': ['env9'],
#               'organisation': ['org4'],
#               'team': ['team4']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.494',
#   'description': 'API Management mex01 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.226',
#   'invoiceEndDate': '2019-01-08 01:30:00.975',
#   'invoiceStartDate': '2019-01-02 01:30:00.983',
#   'orderId': '',
#   'pcCustomerTotalCost': '43',
#   'pcCustomerUnitCost': '71',
#   'pcProviderTaxCost': '81',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '71',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_20',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '0',
#   'providerInvoiceId': '106',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1282019',
#   'providerRegion': 'mex01',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-15 01:30:00.541',
#   'serviceStartDate': '2019-01-09 01:30:00.572',
#   'tags': [{'iCloud_98': 'tagValue_98'},
#            {'iCloud_47': 'tagValue_47'},
#            {'iCloud_56': 'tagValue_56'},
#            {'iCloud_12': 'tagValue_12'},
#            {'iCloud_35': 'tagValue_35'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b62'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '7080mumbaiDatastore',
#   'assetParentId': '',
#   'assetType': 'Datastore',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app4'],
#               'environment': ['env13'],
#               'organisation': ['org4'],
#               'team': ['team2']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.281',
#   'description': 'Datastore mumbai 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.948',
#   'invoiceEndDate': '2019-01-08 01:30:00.567',
#   'invoiceStartDate': '2019-01-02 01:30:00.863',
#   'orderId': '',
#   'pcCustomerTotalCost': '37',
#   'pcCustomerUnitCost': '70',
#   'pcProviderTaxCost': '78',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '70',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_21',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '1',
#   'providerInvoiceId': '97',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1862019',
#   'providerRegion': 'mumbai',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-23 01:30:00.729',
#   'serviceStartDate': '2019-01-09 01:30:00.545',
#   'tags': [{'iCloud_42': 'tagValue_42'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b65'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '4686Central USStorage',
#   'assetParentId': '',
#   'assetType': 'Storage',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app4'],
#               'environment': ['env9'],
#               'organisation': ['org4'],
#               'team': ['team1']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.387',
#   'description': 'Storage Central US 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.770',
#   'invoiceEndDate': '2019-01-08 01:30:00.326',
#   'invoiceStartDate': '2019-01-02 01:30:00.954',
#   'orderId': '',
#   'pcCustomerTotalCost': '52',
#   'pcCustomerUnitCost': '38',
#   'pcProviderTaxCost': '56',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '38',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_22',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '0',
#   'providerInvoiceId': '9',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1222019',
#   'providerRegion': 'Central US',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-23 01:30:00.753',
#   'serviceStartDate': '2019-01-09 01:30:00.606',
#   'tags': [{'iCloud_45': 'tagValue_45'},
#            {'iCloud_56': 'tagValue_56'},
#            {'iCloud_4': 'tagValue_4'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b66'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '9434cardfBatch',
#   'assetParentId': '',
#   'assetType': 'Batch',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app8'],
#               'environment': ['env15'],
#               'organisation': ['org5'],
#               'team': ['team3']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.979',
#   'description': 'Batch cardf 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.956',
#   'invoiceEndDate': '2019-01-08 01:30:00.434',
#   'invoiceStartDate': '2019-01-02 01:30:00.919',
#   'orderId': '',
#   'pcCustomerTotalCost': '2',
#   'pcCustomerUnitCost': '67',
#   'pcProviderTaxCost': '78',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '67',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_22',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '1',
#   'providerInvoiceId': '94',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1922019',
#   'providerRegion': 'cardf',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-25 01:30:00.668',
#   'serviceStartDate': '2019-01-09 01:30:00.454',
#   'tags': [{'iCloud_45': 'tagValue_45'},
#            {'iCloud_56': 'tagValue_56'},
#            {'iCloud_4': 'tagValue_4'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b74'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '6898asia-east1Datastore',
#   'assetParentId': '',
#   'assetType': 'Datastore',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app1'],
#               'environment': ['env12'],
#               'organisation': ['org2'],
#               'team': ['team3']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.703',
#   'description': 'Datastore asia-east1 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.820',
#   'invoiceEndDate': '2019-01-08 01:30:00.893',
#   'invoiceStartDate': '2019-01-02 01:30:00.646',
#   'orderId': '',
#   'pcCustomerTotalCost': '55',
#   'pcCustomerUnitCost': '19',
#   'pcProviderTaxCost': '15',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '19',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_25',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '0',
#   'providerInvoiceId': '7',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1742019',
#   'providerRegion': 'asia-east1',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-14 01:30:00.835',
#   'serviceStartDate': '2019-01-09 01:30:00.697',
#   'tags': [{'iCloud_6': 'tagValue_6'},
#            {'iCloud_13': 'tagValue_13'},
#            {'iCloud_43': 'tagValue_43'},
#            {'iCloud_15': 'tagValue_15'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b75'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '7086brazilsouthVirtualMachine',
#   'assetParentId': '',
#   'assetType': 'VirtualMachine',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app2'],
#               'environment': ['env5'],
#               'organisation': ['org2'],
#               'team': ['team1']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.997',
#   'description': 'VirtualMachine brazilsouth 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.765',
#   'invoiceEndDate': '2019-01-08 01:30:00.638',
#   'invoiceStartDate': '2019-01-02 01:30:00.789',
#   'orderId': '',
#   'pcCustomerTotalCost': '6',
#   'pcCustomerUnitCost': '94',
#   'pcProviderTaxCost': '68',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '94',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_25',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '0',
#   'providerInvoiceId': '85',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1552019',
#   'providerRegion': 'brazilsouth',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-29 01:30:00.971',
#   'serviceStartDate': '2019-01-09 01:30:00.185',
#   'tags': [{'iCloud_6': 'tagValue_6'},
#            {'iCloud_13': 'tagValue_13'},
#            {'iCloud_43': 'tagValue_43'},
#            {'iCloud_15': 'tagValue_15'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b7b'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '7115francecenAutomation and Control',
#   'assetParentId': '',
#   'assetType': 'Automation and Control',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app2'],
#               'environment': ['env14'],
#               'organisation': ['org5'],
#               'team': ['team4']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.360',
#   'description': 'Automation and Control francecen 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.679',
#   'invoiceEndDate': '2019-01-08 01:30:00.561',
#   'invoiceStartDate': '2019-01-02 01:30:00.125',
#   'orderId': '',
#   'pcCustomerTotalCost': '14',
#   'pcCustomerUnitCost': '64',
#   'pcProviderTaxCost': '74',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '64',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_26',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '1',
#   'providerInvoiceId': '119',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1302019',
#   'providerRegion': 'francecen',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-18 01:30:00.647',
#   'serviceStartDate': '2019-01-09 01:30:00.728',
#   'tags': [{'iCloud_88': 'tagValue_88'},
#            {'iCloud_54': 'tagValue_54'},
#            {'iCloud_43': 'tagValue_43'},
#            {'iCloud_63': 'tagValue_63'},
#            {'iCloud_7': 'tagValue_7'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b81'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '1615mex01Microsoft.Compute/disks',
#   'assetParentId': '',
#   'assetType': 'Microsoft.Compute/disks',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app2'],
#               'environment': ['env1'],
#               'organisation': ['org3'],
#               'team': ['team1']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.803',
#   'description': 'Microsoft.Compute/disks mex01 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.460',
#   'invoiceEndDate': '2019-01-08 01:30:00.347',
#   'invoiceStartDate': '2019-01-02 01:30:00.698',
#   'orderId': '',
#   'pcCustomerTotalCost': '69',
#   'pcCustomerUnitCost': '26',
#   'pcProviderTaxCost': '1',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '26',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_27',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '1',
#   'providerInvoiceId': '113',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1422019',
#   'providerRegion': 'mex01',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-15 01:30:00.518',
#   'serviceStartDate': '2019-01-09 01:30:00.817',
#   'tags': [{'iCloud_2': 'tagValue_2'},
#            {'iCloud_88': 'tagValue_88'},
#            {'iCloud_14': 'tagValue_14'},
#            {'iCloud_16': 'tagValue_16'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b82'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '7546japaneastAutomation and Control',
#   'assetParentId': '',
#   'assetType': 'Automation and Control',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app1'],
#               'environment': ['env12'],
#               'organisation': ['org4'],
#               'team': ['team5']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.649',
#   'description': 'Automation and Control japaneast 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.543',
#   'invoiceEndDate': '2019-01-08 01:30:00.750',
#   'invoiceStartDate': '2019-01-02 01:30:00.238',
#   'orderId': '',
#   'pcCustomerTotalCost': '90',
#   'pcCustomerUnitCost': '74',
#   'pcProviderTaxCost': '98',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '74',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_28',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '1',
#   'providerInvoiceId': '10',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1562019',
#   'providerRegion': 'japaneast',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-24 01:30:00.476',
#   'serviceStartDate': '2019-01-09 01:30:00.454',
#   'tags': [{'iCloud_51': 'tagValue_51'},
#            {'iCloud_85': 'tagValue_85'},
#            {'iCloud_52': 'tagValue_52'},
#            {'iCloud_54': 'tagValue_54'}],
#   'unitOfMeasure': 'Percent'},
#  {'_id': ObjectId('5d1313cbf67cd43a0cab6b84'),
#   'assetAccountId': '1Million_data_24june_ba0_aa0',
#   'assetName': '3502Central USDatastore',
#   'assetParentId': '',
#   'assetType': 'Datastore',
#   'billingAccountId': '1Million_data_24june_ba0',
#   'context': {'application': ['app5'],
#               'environment': ['env18'],
#               'organisation': ['org4'],
#               'team': ['team2']},
#   'correlationAssetId': '',
#   'customerConversionRate': '1',
#   'customerCurrency': 'USD',
#   'customerCurrencyDate': '2019-01-30 05:30:00.411',
#   'description': 'Datastore Central US 1Million_data_24june',
#   'extractDate': '2019-01-08 01:30:00.648',
#   'invoiceEndDate': '2019-01-08 01:30:00.714',
#   'invoiceStartDate': '2019-01-02 01:30:00.435',
#   'orderId': '',
#   'pcCustomerTotalCost': '35',
#   'pcCustomerUnitCost': '69',
#   'pcProviderTaxCost': '87',
#   'pcProviderTotalCost': 32.0,
#   'pcProviderUnitCost': '69',
#   'period': '201906',
#   'providerAssetId': 'subscriptions_1Million_data_24june_ba0_1Million_data_24june_ba0_aa0_resourceGroupsdefault_1Million_data_24june_28',
#   'providerCurrency': 'USD',
#   'providerFinalBillFlag': '1',
#   'providerInvoiceId': '72',
#   'providerName': '1Million_data_24june',
#   'providerRecordId': '1382019',
#   'providerRegion': 'Central US',
#   'providerServiceDescription': '',
#   'quantity': '0',
#   'serviceEndDate': '2019-01-25 01:30:00.640',
#   'serviceStartDate': '2019-01-09 01:30:00.337',
#   'tags': [{'iCloud_51': 'tagValue_51'},
#            {'iCloud_85': 'tagValue_85'},
#            {'iCloud_52': 'tagValue_52'},
#            {'iCloud_54': 'tagValue_54'}],
#   'unitOfMeasure': 'Percent'}]
# --- 0.47958827018737793 seconds ---

# %% [markdown]
# ## On reducing the data by match query

# %%
match_stage = {"$match": {"provider_code": "aws", "provider_account": "4565435"}}
application_match_stage = {"$match": {"context.application": {"$in": ['ecommerce_app', 'finance_app']}}}
project_stage = {"$project": {"_id":0, "type": 1, "context": 1}}
unwind_stage = {"$unwind": "$context.application"}
#sort_stage = {"$sort": {"context.application": 1}}
groupby_stage = {"$group": {"_id": {"app": "$context.application", "type": "$type"}, "sum": {"$sum": 1}}}
#cosmetic_output = {"$group": {"_id": "$_id.app", "data": {"$push": {"type": "$_id.type", "count": "$sum"}}}}
#rename_id = {"$project": {"_id": 0, "application": "$_id", "data": 1}}

# %%
import time
start_time = time.time()

pprint.pprint(list(db.inventory.aggregate([match_stage, application_match_stage, project_stage, unwind_stage, groupby_stage], allowDiskUse=True)))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# [{'_id': {'app': 'ecommerce_app', 'type': 'independent_component'},
#   'sum': 6331},
#  {'_id': {'app': 'ecommerce_app', 'type': 'service_instance'}, 'sum': 22066},
#  {'_id': {'app': 'finance_app', 'type': 'independent_component'}, 'sum': 6369},
#  {'_id': {'app': 'finance_app', 'type': 'service_instance'}, 'sum': 22358}]
# --- 1.9217121601104736 seconds ---

# %%
record_count = {"$group": {"_id": "", "sum": {"$sum": 1}}}

# %%
pprint.pprint(list(db.inventory.aggregate([match_stage, application_match_stage, record_count], allowDiskUse=True)))
# Out:
# [{'_id': '', 'sum': 57124}]

# %%
match_stage = {"$match": {"provider_code": "aws", "provider_account": {"$in": ["4565435"]}}}
application_stage = {"$match": {"context.application": {"$in": ["cam", "aiops", "d2ops", "store"]}}}
env_stage = {"$match": {"context.environment": {"$in": ["dev", "uat", "qa"]}}}
project_stage = {"$project": {"_id":0, "type": 1, "context": 1, "provider_resource_name": 1}}
# unwind_stage = {"$unwind": "$context.application"}
sort_stage = {"$sort": {"provider_resource_name": -1}}
limit_stage = {"$limit": 50}

#groupby_stage = {"$group": {"_id": {"app": "$context.application", "type": "$type"}, "sum": {"$sum": 1}}}
#cosmetic_output = {"$group": {"_id": "$_id.app", "data": {"$push": {"type": "$_id.type", "count": "$sum"}}}}
#rename_id = {"$project": {"_id": 0, "application": "$_id", "data": 1}}

# %%
import time
start_time = time.time()

pprint.pprint(list(db.inventory.aggregate([match_stage, application_stage, env_stage, sort_stage, limit_stage], allowDiskUse=True)))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# [{'_id': ObjectId('5d0b5d4a619bfc6d15ec5ae7'),
#   'context': {'application': ['store'], 'environment': ['qa']},
#   'location': {'availability_zone_code': ['cn-north-1a', 'cn-north-1b'],
#                'region_code': 'cn-north-1'},
#   'manage': '',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'NS6QEF1NNXC2I0TGCZF6UGM3UYRRN9K48V26ZCR9S77LF4ELQQQVACVXG0U6I0KT6',
#                            'value': 'ARB1XJYDZZ3P9IHEL4I3V1K8W3DC9LOG18MDX200YJHZZ'},
#   'provider_resource_name': 'VPC - ffd032e3-8010-4d68-8aa3-afa0dc5938c6',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5d4a619bfc6d15ec5ae9'),
#   'context': {'application': ['store'], 'environment': ['qa']},
#   'location': {'availability_zone_code': ['cn-north-1a', 'cn-north-1b'],
#                'region_code': 'cn-north-1'},
#   'manage': '',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'NS6QEF1NNXC2I0TGCZF6UGM3UYRRN9K48V26ZCR9S77LF4ELQQQVACVXG0U6I0KT6',
#                            'value': 'ARB1XJYDZZ3P9IHEL4I3V1K8W3DC9LOG18MDX200YJHZZ'},
#   'provider_resource_name': 'VPC - ffd032e3-8010-4d68-8aa3-afa0dc5938c6',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5d4a619bfc6d15ec5aea'),
#   'context': {'application': ['store'], 'environment': ['qa']},
#   'location': {'availability_zone_code': ['cn-north-1a', 'cn-north-1b'],
#                'region_code': 'cn-north-1'},
#   'manage': '',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'NS6QEF1NNXC2I0TGCZF6UGM3UYRRN9K48V26ZCR9S77LF4ELQQQVACVXG0U6I0KT6',
#                            'value': 'ARB1XJYDZZ3P9IHEL4I3V1K8W3DC9LOG18MDX200YJHZZ'},
#   'provider_resource_name': 'VPC - ffd032e3-8010-4d68-8aa3-afa0dc5938c6',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5d4a619bfc6d15ec5ae8'),
#   'context': {'application': ['store'], 'environment': ['qa']},
#   'location': {'availability_zone_code': ['cn-north-1a', 'cn-north-1b'],
#                'region_code': 'cn-north-1'},
#   'manage': '',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'NS6QEF1NNXC2I0TGCZF6UGM3UYRRN9K48V26ZCR9S77LF4ELQQQVACVXG0U6I0KT6',
#                            'value': 'ARB1XJYDZZ3P9IHEL4I3V1K8W3DC9LOG18MDX200YJHZZ'},
#   'provider_resource_name': 'VPC - ffd032e3-8010-4d68-8aa3-afa0dc5938c6',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5d4a619bfc6d15ec5aec'),
#   'context': {'application': ['store'], 'environment': ['qa']},
#   'location': {'availability_zone_code': ['cn-north-1a', 'cn-north-1b'],
#                'region_code': 'cn-north-1'},
#   'manage': '',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'NS6QEF1NNXC2I0TGCZF6UGM3UYRRN9K48V26ZCR9S77LF4ELQQQVACVXG0U6I0KT6',
#                            'value': 'ARB1XJYDZZ3P9IHEL4I3V1K8W3DC9LOG18MDX200YJHZZ'},
#   'provider_resource_name': 'VPC - ffd032e3-8010-4d68-8aa3-afa0dc5938c6',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5d4a619bfc6d15ec5aeb'),
#   'context': {'application': ['store'], 'environment': ['qa']},
#   'location': {'availability_zone_code': ['cn-north-1a', 'cn-north-1b'],
#                'region_code': 'cn-north-1'},
#   'manage': '',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'NS6QEF1NNXC2I0TGCZF6UGM3UYRRN9K48V26ZCR9S77LF4ELQQQVACVXG0U6I0KT6',
#                            'value': 'ARB1XJYDZZ3P9IHEL4I3V1K8W3DC9LOG18MDX200YJHZZ'},
#   'provider_resource_name': 'VPC - ffd032e3-8010-4d68-8aa3-afa0dc5938c6',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5d7c619bfc6d15ecb523'),
#   'context': {'application': ['d2ops'], 'environment': ['dev']},
#   'location': {'availability_zone_code': ['ap-northeast-3a'],
#                'region_code': 'ap-northeast-3'},
#   'manage': '',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'EI3TBKGSP1POEX1J49VWWFKJ6UEUBWIA0ZXNPUCHFSZQLOQ1NFCSUHX9ATVOYYNNF',
#                            'value': '1YJSV8J4CEGCL2G6SZTM2O4V2Y38DSGCX3XDG9RGPWG65'},
#   'provider_resource_name': 'VPC - ffbceecb-15fe-49c3-b53d-54ee0a3acae6',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'independent_component'},
#  {'_id': ObjectId('5d0b5cf7619bfc6d15ebd33a'),
#   'context': {'application': ['aiops'], 'environment': ['dev']},
#   'location': {'availability_zone_code': ['eu-central-1a',
#                                           'eu-central-1b',
#                                           'eu-central-1c'],
#                'region_code': 'eu-central-1'},
#   'manage': 'enterprise_it',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': '5OPYH9KKH534SYAY61WOREDMHG9WNOMKWY9QTF489U1EGFMH9486EXCBGM0PL8QR4',
#                            'value': 'ND622VRBXRNH6A9C4BPJQ5UZ5LNE7VUYHK1XJTBNMQJ10'},
#   'provider_resource_name': 'VPC - ffb9f769-1b25-45a6-9498-1396c00d8d5d',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5cf7619bfc6d15ebd338'),
#   'context': {'application': ['aiops'], 'environment': ['dev']},
#   'location': {'availability_zone_code': ['eu-central-1a',
#                                           'eu-central-1b',
#                                           'eu-central-1c'],
#                'region_code': 'eu-central-1'},
#   'manage': 'enterprise_it',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': '5OPYH9KKH534SYAY61WOREDMHG9WNOMKWY9QTF489U1EGFMH9486EXCBGM0PL8QR4',
#                            'value': 'ND622VRBXRNH6A9C4BPJQ5UZ5LNE7VUYHK1XJTBNMQJ10'},
#   'provider_resource_name': 'VPC - ffb9f769-1b25-45a6-9498-1396c00d8d5d',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5cf7619bfc6d15ebd339'),
#   'context': {'application': ['aiops'], 'environment': ['dev']},
#   'location': {'availability_zone_code': ['eu-central-1a',
#                                           'eu-central-1b',
#                                           'eu-central-1c'],
#                'region_code': 'eu-central-1'},
#   'manage': 'enterprise_it',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': '5OPYH9KKH534SYAY61WOREDMHG9WNOMKWY9QTF489U1EGFMH9486EXCBGM0PL8QR4',
#                            'value': 'ND622VRBXRNH6A9C4BPJQ5UZ5LNE7VUYHK1XJTBNMQJ10'},
#   'provider_resource_name': 'VPC - ffb9f769-1b25-45a6-9498-1396c00d8d5d',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5e39619bfc6d15ededd1'),
#   'context': {'application': ['cam'], 'environment': ['qa']},
#   'location': {'availability_zone_code': ['us-east-2a',
#                                           'us-east-2b',
#                                           'us-east-2c'],
#                'region_code': 'us-east-2'},
#   'manage': 'ibm_managed',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'B29C56XORU4XSSV9WCAIF8M4SKTZ0JV85L33DTFHUZUHVLJY7BCR8PSKZHGGUHQ81',
#                            'value': 'JGG8SNFGEVJQ6HIDFACCDJKZ01NJYEPUR4QPE08XBS1DT'},
#   'provider_resource_name': 'VPC - ffb788e8-d32a-4ee1-b1b2-f351258e9d4e',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5d35619bfc6d15ec37c4'),
#   'context': {'application': ['cam'], 'environment': ['uat']},
#   'location': {'availability_zone_code': ['us-east-2a',
#                                           'us-east-2b',
#                                           'us-east-2c'],
#                'region_code': 'us-east-2'},
#   'manage': 'third_party',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': '0OCE2LWPQ0YS9WBICVLUON3ACC4LUYAVI9KVZZO7V7D6L1FDPZRE477DIMA08O3KR',
#                            'value': '5RVPMJJSCEUIMX0EOK8WDVJ41S6QI8AXSZ994U22T5GAA'},
#   'provider_resource_name': 'VPC - ffb3faa9-3cd4-4b0b-acb3-2b21b213755d',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'independent_component'},
#  {'_id': ObjectId('5d0b5dbe619bfc6d15ed1b8d'),
#   'context': {'application': ['cam'], 'environment': ['dev']},
#   'location': {'availability_zone_code': ['sa-east-1a',
#                                           'sa-east-1b',
#                                           'sa-east-1c'],
#                'region_code': 'sa-east-1'},
#   'manage': 'enterprise_it',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'EPASNHSA7UU8JLXU8KLNGWZRV9RSH83QCTTMWJX9BHR75QGDVRBE356DWDZ0ANL99',
#                            'value': 'OAGZ3GOQJWSQDJQN5PSXNJHKUKGN3CAT4H9DRC2KASMUI'},
#   'provider_resource_name': 'VPC - ffabe778-c872-4c07-a915-e9f41d83e83d',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5dbe619bfc6d15ed1b8c'),
#   'context': {'application': ['cam'], 'environment': ['dev']},
#   'location': {'availability_zone_code': ['sa-east-1a',
#                                           'sa-east-1b',
#                                           'sa-east-1c'],
#                'region_code': 'sa-east-1'},
#   'manage': 'enterprise_it',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'EPASNHSA7UU8JLXU8KLNGWZRV9RSH83QCTTMWJX9BHR75QGDVRBE356DWDZ0ANL99',
#                            'value': 'OAGZ3GOQJWSQDJQN5PSXNJHKUKGN3CAT4H9DRC2KASMUI'},
#   'provider_resource_name': 'VPC - ffabe778-c872-4c07-a915-e9f41d83e83d',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5dbe619bfc6d15ed1b8b'),
#   'context': {'application': ['cam'], 'environment': ['dev']},
#   'location': {'availability_zone_code': ['sa-east-1a',
#                                           'sa-east-1b',
#                                           'sa-east-1c'],
#                'region_code': 'sa-east-1'},
#   'manage': 'enterprise_it',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'EPASNHSA7UU8JLXU8KLNGWZRV9RSH83QCTTMWJX9BHR75QGDVRBE356DWDZ0ANL99',
#                            'value': 'OAGZ3GOQJWSQDJQN5PSXNJHKUKGN3CAT4H9DRC2KASMUI'},
#   'provider_resource_name': 'VPC - ffabe778-c872-4c07-a915-e9f41d83e83d',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5dbe619bfc6d15ed1b8f'),
#   'context': {'application': ['cam'], 'environment': ['dev']},
#   'location': {'availability_zone_code': ['sa-east-1a',
#                                           'sa-east-1b',
#                                           'sa-east-1c'],
#                'region_code': 'sa-east-1'},
#   'manage': 'enterprise_it',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'EPASNHSA7UU8JLXU8KLNGWZRV9RSH83QCTTMWJX9BHR75QGDVRBE356DWDZ0ANL99',
#                            'value': 'OAGZ3GOQJWSQDJQN5PSXNJHKUKGN3CAT4H9DRC2KASMUI'},
#   'provider_resource_name': 'VPC - ffabe778-c872-4c07-a915-e9f41d83e83d',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5dbe619bfc6d15ed1b8e'),
#   'context': {'application': ['cam'], 'environment': ['dev']},
#   'location': {'availability_zone_code': ['sa-east-1a',
#                                           'sa-east-1b',
#                                           'sa-east-1c'],
#                'region_code': 'sa-east-1'},
#   'manage': 'enterprise_it',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'EPASNHSA7UU8JLXU8KLNGWZRV9RSH83QCTTMWJX9BHR75QGDVRBE356DWDZ0ANL99',
#                            'value': 'OAGZ3GOQJWSQDJQN5PSXNJHKUKGN3CAT4H9DRC2KASMUI'},
#   'provider_resource_name': 'VPC - ffabe778-c872-4c07-a915-e9f41d83e83d',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5e10619bfc6d15eda623'),
#   'context': {'application': ['cam'], 'environment': ['dev']},
#   'location': {'availability_zone_code': ['ap-southeast-2a',
#                                           'ap-southeast-2b',
#                                           'ap-southeast-2c'],
#                'region_code': 'ap-southeast-2'},
#   'manage': 'third_party',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'Q6WSLXOTSSI9MIJHZEQA1UWJ752VR1G6BENNHFQTOUTGXETP01CXOP794CMWBU17B',
#                            'value': 'R4C7B6639WC4G9A260XST5UHUQAAYEGPQJ22FKTSWEKGA'},
#   'provider_resource_name': 'VPC - ffaa72b5-3b79-4917-ac36-6669da61f455',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'independent_component'},
#  {'_id': ObjectId('5d0b5da5619bfc6d15ecf49d'),
#   'context': {'application': ['cam'], 'environment': ['dev']},
#   'location': {'availability_zone_code': ['us-east-1a',
#                                           'us-east-1b',
#                                           'us-east-1c',
#                                           'us-east-1d',
#                                           'us-east-1e',
#                                           'us-east-1f'],
#                'region_code': 'us-east-1'},
#   'manage': 'enterprise_it',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'XMKC8DXIPQBEL5HTO0ZRLHMLPTALU3TJCOJB6PHVPLLN9LQ0CQC1E7JURF6MRBT3C',
#                            'value': '1ZEMGD5S149CE3OI6H92BG20HYLEQ3N3OGA82SQ43CS7F'},
#   'provider_resource_name': 'VPC - ff9d32c6-fb5c-4be9-be73-f0333ffba91e',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5da5619bfc6d15ecf49a'),
#   'context': {'application': ['cam'], 'environment': ['dev']},
#   'location': {'availability_zone_code': ['us-east-1a',
#                                           'us-east-1b',
#                                           'us-east-1c',
#                                           'us-east-1d',
#                                           'us-east-1e',
#                                           'us-east-1f'],
#                'region_code': 'us-east-1'},
#   'manage': 'enterprise_it',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'XMKC8DXIPQBEL5HTO0ZRLHMLPTALU3TJCOJB6PHVPLLN9LQ0CQC1E7JURF6MRBT3C',
#                            'value': '1ZEMGD5S149CE3OI6H92BG20HYLEQ3N3OGA82SQ43CS7F'},
#   'provider_resource_name': 'VPC - ff9d32c6-fb5c-4be9-be73-f0333ffba91e',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5da5619bfc6d15ecf49e'),
#   'context': {'application': ['cam'], 'environment': ['dev']},
#   'location': {'availability_zone_code': ['us-east-1a',
#                                           'us-east-1b',
#                                           'us-east-1c',
#                                           'us-east-1d',
#                                           'us-east-1e',
#                                           'us-east-1f'],
#                'region_code': 'us-east-1'},
#   'manage': 'enterprise_it',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'XMKC8DXIPQBEL5HTO0ZRLHMLPTALU3TJCOJB6PHVPLLN9LQ0CQC1E7JURF6MRBT3C',
#                            'value': '1ZEMGD5S149CE3OI6H92BG20HYLEQ3N3OGA82SQ43CS7F'},
#   'provider_resource_name': 'VPC - ff9d32c6-fb5c-4be9-be73-f0333ffba91e',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5da5619bfc6d15ecf499'),
#   'context': {'application': ['cam'], 'environment': ['dev']},
#   'location': {'availability_zone_code': ['us-east-1a',
#                                           'us-east-1b',
#                                           'us-east-1c',
#                                           'us-east-1d',
#                                           'us-east-1e',
#                                           'us-east-1f'],
#                'region_code': 'us-east-1'},
#   'manage': 'enterprise_it',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'XMKC8DXIPQBEL5HTO0ZRLHMLPTALU3TJCOJB6PHVPLLN9LQ0CQC1E7JURF6MRBT3C',
#                            'value': '1ZEMGD5S149CE3OI6H92BG20HYLEQ3N3OGA82SQ43CS7F'},
#   'provider_resource_name': 'VPC - ff9d32c6-fb5c-4be9-be73-f0333ffba91e',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5da5619bfc6d15ecf49b'),
#   'context': {'application': ['cam'], 'environment': ['dev']},
#   'location': {'availability_zone_code': ['us-east-1a',
#                                           'us-east-1b',
#                                           'us-east-1c',
#                                           'us-east-1d',
#                                           'us-east-1e',
#                                           'us-east-1f'],
#                'region_code': 'us-east-1'},
#   'manage': 'enterprise_it',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'XMKC8DXIPQBEL5HTO0ZRLHMLPTALU3TJCOJB6PHVPLLN9LQ0CQC1E7JURF6MRBT3C',
#                            'value': '1ZEMGD5S149CE3OI6H92BG20HYLEQ3N3OGA82SQ43CS7F'},
#   'provider_resource_name': 'VPC - ff9d32c6-fb5c-4be9-be73-f0333ffba91e',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5da5619bfc6d15ecf49c'),
#   'context': {'application': ['cam'], 'environment': ['dev']},
#   'location': {'availability_zone_code': ['us-east-1a',
#                                           'us-east-1b',
#                                           'us-east-1c',
#                                           'us-east-1d',
#                                           'us-east-1e',
#                                           'us-east-1f'],
#                'region_code': 'us-east-1'},
#   'manage': 'enterprise_it',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'XMKC8DXIPQBEL5HTO0ZRLHMLPTALU3TJCOJB6PHVPLLN9LQ0CQC1E7JURF6MRBT3C',
#                            'value': '1ZEMGD5S149CE3OI6H92BG20HYLEQ3N3OGA82SQ43CS7F'},
#   'provider_resource_name': 'VPC - ff9d32c6-fb5c-4be9-be73-f0333ffba91e',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5e2b619bfc6d15edd622'),
#   'context': {'application': ['aiops'], 'environment': ['qa']},
#   'location': {'availability_zone_code': ['cn-north-1a', 'cn-north-1b'],
#                'region_code': 'cn-north-1'},
#   'manage': '',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'B2BYSHQQUTZ8QN1UDJBSOJJPUXNZXXZNTLO7BZA7DOZKSEC3RWXGLBYPZU3B73HYJ',
#                            'value': 'SQOXHHOXKRIQLSA7CK52BHGNVM1YFJ9Y3LBQCWSJYKXQU'},
#   'provider_resource_name': 'VPC - ff9a21f4-89e4-4b65-9e63-b2157216003f',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'independent_component'},
#  {'_id': ObjectId('5d0b5e37619bfc6d15ede90e'),
#   'context': {'application': ['cam'], 'environment': ['uat']},
#   'location': {'availability_zone_code': ['ap-southeast-1a',
#                                           'ap-southeast-1b',
#                                           'ap-southeast-1c'],
#                'region_code': 'ap-southeast-1'},
#   'manage': 'third_party',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'WRPRQUPNOXC0UVDRQ2ST5SW4C3Y6MWUZUNIWEMZNW7AIF67M87QQD0XMHV6CY0FM8',
#                            'value': 'GE3SSVPYQQD5UDPW5ZA2N4II41P4RCT7BZ90A0CY0YS1G'},
#   'provider_resource_name': 'VPC - ff8d94c6-d454-40b1-8623-e9ee203eae24',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'independent_component'},
#  {'_id': ObjectId('5d0b5cc0619bfc6d15eb7445'),
#   'context': {'application': ['store'], 'environment': ['uat']},
#   'location': {'availability_zone_code': ['us-east-2a',
#                                           'us-east-2b',
#                                           'us-east-2c'],
#                'region_code': 'us-east-2'},
#   'manage': 'third_party',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'YCHYWPLX0C38NXM85OYC2YN276LPDBO6DT8F11DZ3DDNCZJQBF8KKVM0H9BKCEY78',
#                            'value': '99874FLFQC4HYXOGGE700UMB5Y0OAJ66YDFCZU23CFXUR'},
#   'provider_resource_name': 'VPC - ff8301c6-de23-44f1-8c05-3711061301c2',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'independent_component'},
#  {'_id': ObjectId('5d0b5d99619bfc6d15ecdf5e'),
#   'context': {'application': ['cam'], 'environment': ['uat']},
#   'location': {'availability_zone_code': ['ap-northeast-3a'],
#                'region_code': 'ap-northeast-3'},
#   'manage': 'ibm_managed',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'MZF6Z6TZZEGADPMWQEUV48Z0ZRCRJZA3W56FBT6UGPZ36DJEK9OKQQKN5SVMXO3XM',
#                            'value': 'K4BWWA1T3H8N2VM4JQ2D7DZBU5QJO3MIABBUES9L3E3CC'},
#   'provider_resource_name': 'VPC - ff783f49-41f6-4bec-bf43-736d04702f95',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5d99619bfc6d15ecdf5f'),
#   'context': {'application': ['cam'], 'environment': ['uat']},
#   'location': {'availability_zone_code': ['ap-northeast-3a'],
#                'region_code': 'ap-northeast-3'},
#   'manage': 'ibm_managed',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'MZF6Z6TZZEGADPMWQEUV48Z0ZRCRJZA3W56FBT6UGPZ36DJEK9OKQQKN5SVMXO3XM',
#                            'value': 'K4BWWA1T3H8N2VM4JQ2D7DZBU5QJO3MIABBUES9L3E3CC'},
#   'provider_resource_name': 'VPC - ff783f49-41f6-4bec-bf43-736d04702f95',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5d99619bfc6d15ecdf5b'),
#   'context': {'application': ['cam'], 'environment': ['uat']},
#   'location': {'availability_zone_code': ['ap-northeast-3a'],
#                'region_code': 'ap-northeast-3'},
#   'manage': 'ibm_managed',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'MZF6Z6TZZEGADPMWQEUV48Z0ZRCRJZA3W56FBT6UGPZ36DJEK9OKQQKN5SVMXO3XM',
#                            'value': 'K4BWWA1T3H8N2VM4JQ2D7DZBU5QJO3MIABBUES9L3E3CC'},
#   'provider_resource_name': 'VPC - ff783f49-41f6-4bec-bf43-736d04702f95',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5d99619bfc6d15ecdf5c'),
#   'context': {'application': ['cam'], 'environment': ['uat']},
#   'location': {'availability_zone_code': ['ap-northeast-3a'],
#                'region_code': 'ap-northeast-3'},
#   'manage': 'ibm_managed',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'MZF6Z6TZZEGADPMWQEUV48Z0ZRCRJZA3W56FBT6UGPZ36DJEK9OKQQKN5SVMXO3XM',
#                            'value': 'K4BWWA1T3H8N2VM4JQ2D7DZBU5QJO3MIABBUES9L3E3CC'},
#   'provider_resource_name': 'VPC - ff783f49-41f6-4bec-bf43-736d04702f95',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5d99619bfc6d15ecdf5d'),
#   'context': {'application': ['cam'], 'environment': ['uat']},
#   'location': {'availability_zone_code': ['ap-northeast-3a'],
#                'region_code': 'ap-northeast-3'},
#   'manage': 'ibm_managed',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'MZF6Z6TZZEGADPMWQEUV48Z0ZRCRJZA3W56FBT6UGPZ36DJEK9OKQQKN5SVMXO3XM',
#                            'value': 'K4BWWA1T3H8N2VM4JQ2D7DZBU5QJO3MIABBUES9L3E3CC'},
#   'provider_resource_name': 'VPC - ff783f49-41f6-4bec-bf43-736d04702f95',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5cbb619bfc6d15eb6ce8'),
#   'context': {'application': ['d2ops'], 'environment': ['qa']},
#   'location': {'availability_zone_code': ['ap-northeast-3a'],
#                'region_code': 'ap-northeast-3'},
#   'manage': 'third_party',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'E9Y7KEMMF1U20PY3Y05RPML9KCMUH2YHI18XCX6IU2UBPGGCA7U1OKR70ELLZPQNH',
#                            'value': '8TSAC3YFM8L8J2Q4HK34EYKVUMI9ZEU5T38ITXA7NMBSO'},
#   'provider_resource_name': 'VPC - ff6c6a6c-8d9c-4e72-ba7e-98539d4294c4',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5cbb619bfc6d15eb6ce7'),
#   'context': {'application': ['d2ops'], 'environment': ['qa']},
#   'location': {'availability_zone_code': ['ap-northeast-3a'],
#                'region_code': 'ap-northeast-3'},
#   'manage': 'third_party',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'E9Y7KEMMF1U20PY3Y05RPML9KCMUH2YHI18XCX6IU2UBPGGCA7U1OKR70ELLZPQNH',
#                            'value': '8TSAC3YFM8L8J2Q4HK34EYKVUMI9ZEU5T38ITXA7NMBSO'},
#   'provider_resource_name': 'VPC - ff6c6a6c-8d9c-4e72-ba7e-98539d4294c4',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5df4619bfc6d15ed8028'),
#   'context': {'application': ['aiops'], 'environment': ['qa']},
#   'location': {'availability_zone_code': ['eu-west-2a',
#                                           'eu-west-2b',
#                                           'eu-west-2c'],
#                'region_code': 'eu-west-2'},
#   'manage': 'third_party',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'L3W8F1PIRLVYWGEJ83U3RKOHODAER6K4R9J6YNNR1L7BBFTYGMNUX2DEDI0BGCDJZ',
#                            'value': 'KG6I64KUB8WOK2DYGIEIPLYBFJA1JCGNNWUTYDVMVDRZZ'},
#   'provider_resource_name': 'VPC - ff63fe11-24ad-49fc-9e15-935bde222f41',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5d49619bfc6d15ec5838'),
#   'context': {'application': ['aiops'], 'environment': ['uat']},
#   'location': {'availability_zone_code': ['eu-west-2a',
#                                           'eu-west-2b',
#                                           'eu-west-2c'],
#                'region_code': 'eu-west-2'},
#   'manage': '',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'RDQC3QS4E0EUPQ0Q1U5RL00ACJQ1ZQV2BI6EU36Q24QB300UH2UL2ORU69XS4QN0W',
#                            'value': 'J5ISQCLMBR7VH8FR65F8EGZ710KFK8YJ2T92DTE21AWXV'},
#   'provider_resource_name': 'VPC - ff5c3073-c150-485b-9e41-713ef52408ff',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5dc4619bfc6d15ed273f'),
#   'context': {'application': ['d2ops'], 'environment': ['uat']},
#   'location': {'availability_zone_code': ['ap-northeast-2a',
#                                           'ap-northeast-2b',
#                                           'ap-northeast-2c'],
#                'region_code': 'ap-northeast-2'},
#   'manage': 'enterprise_it',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'TPZHYCGLPC5NYAI4DDCLF2JMHO6AA8LWB0AZP0NHA5WXH2WJHCWLPC1I6CQV7TB0E',
#                            'value': 'WYHIUXKWOV4W5PL6IIR5UXI5JN0LDYKZDT6KM6Z44WWDF'},
#   'provider_resource_name': 'VPC - ff3c0055-d1e0-4ed1-9046-02b035d81a9f',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'independent_component'},
#  {'_id': ObjectId('5d0b5dac619bfc6d15ecff25'),
#   'context': {'application': ['cam'], 'environment': ['qa']},
#   'location': {'availability_zone_code': ['us-west-2a',
#                                           'us-west-2b',
#                                           'us-west-2c'],
#                'region_code': 'us-west-2'},
#   'manage': 'enterprise_it',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'NEK96JJ1ZP7VQLPUFFHVN49Z435ACZ9EKOYD2WJFY52DBH5N6QLA5YV29ZE1MR55I',
#                            'value': 'XZ2SH2PAZCPZXD51T357PIM90KE2TWB0IQDNMZV17LMRF'},
#   'provider_resource_name': 'VPC - ff30bc5e-4a4c-471a-8c92-b4daf419bce8',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5dac619bfc6d15ecff27'),
#   'context': {'application': ['cam'], 'environment': ['qa']},
#   'location': {'availability_zone_code': ['us-west-2a',
#                                           'us-west-2b',
#                                           'us-west-2c'],
#                'region_code': 'us-west-2'},
#   'manage': 'enterprise_it',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'NEK96JJ1ZP7VQLPUFFHVN49Z435ACZ9EKOYD2WJFY52DBH5N6QLA5YV29ZE1MR55I',
#                            'value': 'XZ2SH2PAZCPZXD51T357PIM90KE2TWB0IQDNMZV17LMRF'},
#   'provider_resource_name': 'VPC - ff30bc5e-4a4c-471a-8c92-b4daf419bce8',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5dac619bfc6d15ecff26'),
#   'context': {'application': ['cam'], 'environment': ['qa']},
#   'location': {'availability_zone_code': ['us-west-2a',
#                                           'us-west-2b',
#                                           'us-west-2c'],
#                'region_code': 'us-west-2'},
#   'manage': 'enterprise_it',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'NEK96JJ1ZP7VQLPUFFHVN49Z435ACZ9EKOYD2WJFY52DBH5N6QLA5YV29ZE1MR55I',
#                            'value': 'XZ2SH2PAZCPZXD51T357PIM90KE2TWB0IQDNMZV17LMRF'},
#   'provider_resource_name': 'VPC - ff30bc5e-4a4c-471a-8c92-b4daf419bce8',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5dac619bfc6d15ecff28'),
#   'context': {'application': ['cam'], 'environment': ['qa']},
#   'location': {'availability_zone_code': ['us-west-2a',
#                                           'us-west-2b',
#                                           'us-west-2c'],
#                'region_code': 'us-west-2'},
#   'manage': 'enterprise_it',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'NEK96JJ1ZP7VQLPUFFHVN49Z435ACZ9EKOYD2WJFY52DBH5N6QLA5YV29ZE1MR55I',
#                            'value': 'XZ2SH2PAZCPZXD51T357PIM90KE2TWB0IQDNMZV17LMRF'},
#   'provider_resource_name': 'VPC - ff30bc5e-4a4c-471a-8c92-b4daf419bce8',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5e36619bfc6d15ede6bc'),
#   'context': {'application': ['d2ops'], 'environment': ['dev']},
#   'location': {'availability_zone_code': ['ap-northeast-2a',
#                                           'ap-northeast-2b',
#                                           'ap-northeast-2c'],
#                'region_code': 'ap-northeast-2'},
#   'manage': 'third_party',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': '72V0AHR9NZ8PMTDVHTCCBOV8J2PYZARI5C4376530TYQNKXYF1RLK8UJ98921C8VN',
#                            'value': 'J9FAZGU30W5EZXD63RRF2DJSDZBKYWUAA888Y0DI9K0LI'},
#   'provider_resource_name': 'VPC - ff244d42-634b-420b-957a-cd6406034c49',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'independent_component'},
#  {'_id': ObjectId('5d0b5e3c619bfc6d15edf448'),
#   'context': {'application': ['aiops'], 'environment': ['dev']},
#   'location': {'availability_zone_code': ['cn-northwest-1a',
#                                           'cn-northwest-1b',
#                                           'cn-northwest-1c'],
#                'region_code': 'cn-northwest-1'},
#   'manage': 'enterprise_it',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'FNKXLPITIGLJFIFY0SV4X6OJ8CV8QS20S4JKV2ZA4SLEK5N2104GJNUCVGRDPL5T1',
#                            'value': 'JNDE0ANFFY4ZA5FMYL01MWDRWYQ2723SL3GNMR6WS4LF8'},
#   'provider_resource_name': 'VPC - ff183440-ce3d-4edb-bbe6-5bf8579a07dd',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5e3c619bfc6d15edf446'),
#   'context': {'application': ['aiops'], 'environment': ['dev']},
#   'location': {'availability_zone_code': ['cn-northwest-1a',
#                                           'cn-northwest-1b',
#                                           'cn-northwest-1c'],
#                'region_code': 'cn-northwest-1'},
#   'manage': 'enterprise_it',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'FNKXLPITIGLJFIFY0SV4X6OJ8CV8QS20S4JKV2ZA4SLEK5N2104GJNUCVGRDPL5T1',
#                            'value': 'JNDE0ANFFY4ZA5FMYL01MWDRWYQ2723SL3GNMR6WS4LF8'},
#   'provider_resource_name': 'VPC - ff183440-ce3d-4edb-bbe6-5bf8579a07dd',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5e3c619bfc6d15edf445'),
#   'context': {'application': ['aiops'], 'environment': ['dev']},
#   'location': {'availability_zone_code': ['cn-northwest-1a',
#                                           'cn-northwest-1b',
#                                           'cn-northwest-1c'],
#                'region_code': 'cn-northwest-1'},
#   'manage': 'enterprise_it',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'FNKXLPITIGLJFIFY0SV4X6OJ8CV8QS20S4JKV2ZA4SLEK5N2104GJNUCVGRDPL5T1',
#                            'value': 'JNDE0ANFFY4ZA5FMYL01MWDRWYQ2723SL3GNMR6WS4LF8'},
#   'provider_resource_name': 'VPC - ff183440-ce3d-4edb-bbe6-5bf8579a07dd',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5e3c619bfc6d15edf443'),
#   'context': {'application': ['aiops'], 'environment': ['dev']},
#   'location': {'availability_zone_code': ['cn-northwest-1a',
#                                           'cn-northwest-1b',
#                                           'cn-northwest-1c'],
#                'region_code': 'cn-northwest-1'},
#   'manage': 'enterprise_it',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'FNKXLPITIGLJFIFY0SV4X6OJ8CV8QS20S4JKV2ZA4SLEK5N2104GJNUCVGRDPL5T1',
#                            'value': 'JNDE0ANFFY4ZA5FMYL01MWDRWYQ2723SL3GNMR6WS4LF8'},
#   'provider_resource_name': 'VPC - ff183440-ce3d-4edb-bbe6-5bf8579a07dd',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5e3c619bfc6d15edf447'),
#   'context': {'application': ['aiops'], 'environment': ['dev']},
#   'location': {'availability_zone_code': ['cn-northwest-1a',
#                                           'cn-northwest-1b',
#                                           'cn-northwest-1c'],
#                'region_code': 'cn-northwest-1'},
#   'manage': 'enterprise_it',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'FNKXLPITIGLJFIFY0SV4X6OJ8CV8QS20S4JKV2ZA4SLEK5N2104GJNUCVGRDPL5T1',
#                            'value': 'JNDE0ANFFY4ZA5FMYL01MWDRWYQ2723SL3GNMR6WS4LF8'},
#   'provider_resource_name': 'VPC - ff183440-ce3d-4edb-bbe6-5bf8579a07dd',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5e3c619bfc6d15edf444'),
#   'context': {'application': ['aiops'], 'environment': ['dev']},
#   'location': {'availability_zone_code': ['cn-northwest-1a',
#                                           'cn-northwest-1b',
#                                           'cn-northwest-1c'],
#                'region_code': 'cn-northwest-1'},
#   'manage': 'enterprise_it',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'FNKXLPITIGLJFIFY0SV4X6OJ8CV8QS20S4JKV2ZA4SLEK5N2104GJNUCVGRDPL5T1',
#                            'value': 'JNDE0ANFFY4ZA5FMYL01MWDRWYQ2723SL3GNMR6WS4LF8'},
#   'provider_resource_name': 'VPC - ff183440-ce3d-4edb-bbe6-5bf8579a07dd',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'service_instance'},
#  {'_id': ObjectId('5d0b5dbc619bfc6d15ed17b3'),
#   'context': {'application': ['aiops'], 'environment': ['dev']},
#   'location': {'availability_zone_code': ['ap-south-1a', 'ap-south-1b'],
#                'region_code': 'ap-south-1'},
#   'manage': 'ibm_managed',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'EMXG5S589APKQAG5CU1IDB5E1XJ780TDN4CVNMWXUV3QYZM8RI5JCYQGQNQV456U2',
#                            'value': 'D9SYD5PPJ6JMZBMTDN7SH697VLCA4MMYL8X5UGGUYC0F8'},
#   'provider_resource_name': 'VPC - ff13f1b2-7a8c-4a52-868b-42ae6b6953c7',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'independent_component'},
#  {'_id': ObjectId('5d0b5e10619bfc6d15eda6d1'),
#   'context': {'application': ['d2ops'], 'environment': ['uat']},
#   'location': {'availability_zone_code': ['eu-west-1a',
#                                           'eu-west-1b',
#                                           'eu-west-1c'],
#                'region_code': 'eu-west-1'},
#   'manage': 'third_party',
#   'provider_account': '4565435',
#   'provider_account_name': 'test_account_4',
#   'provider_code': 'aws',
#   'provider_resource_id': {'name': 'GGV8NXI07XR5TYK5BXFNUPULI5G1MENSO2EPXJ8F6CLP7MG4TAF3D0XYELTWDBL7N',
#                            'value': 'BSXT7D95UZJXCUAFTDJNVIOBNCP2ZYBNNGEPZRU4SIGRY'},
#   'provider_resource_name': 'VPC - ff13e703-520c-4a53-bd13-0b40d44652a5',
#   'service_category_type': 'network',
#   'status': 'Active',
#   'type': 'independent_component'}]
# --- 3.339611053466797 seconds ---

# %%
db.inventory.find({"provider_code": "aws", "provider_account": {"$in": ["4565435"]}})

# %%
import re
regx = re.compile("ecommerce_app", re.IGNORECASE)
import time
start_time = time.time()
pprint.pprint(list(db.inventory.find({"$text": {"$search": "aws"}})))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-9-89464a51fde9> in <module>
#       3 import time
#       4 start_time = time.time()
# ----> 5 pprint.pprint(list(db.inventory.find({"$provider_code_account": {"$search": "aws"}})))
#       6 print("--- %s seconds ---" % (time.time() - start_time))
#
# /anaconda2/envs/py36/lib/python3.6/site-packages/pymongo/cursor.py in next(self)
#    1187         if self.__empty:
#    1188             raise StopIteration
# -> 1189         if len(self.__data) or self._refresh():
#    1190             if self.__manipulate:
#    1191                 _db = self.__collection.database
#
# /anaconda2/envs/py36/lib/python3.6/site-packages/pymongo/cursor.py in _refresh(self)
#    1102                                   self.__session,
#    1103                                   self.__collection.database.client)
# -> 1104             self.__send_message(q)
#    1105         elif self.__id:  # Get More
#    1106             if self.__limit:
#
# /anaconda2/envs/py36/lib/python3.6/site-packages/pymongo/cursor.py in __send_message(self, operation)
#     980                 first = docs[0]
#     981                 client._receive_cluster_time(first, self.__session)
# --> 982                 helpers._check_command_response(first)
#     983         except OperationFailure as exc:
#     984             self.__killed = True
#
# /anaconda2/envs/py36/lib/python3.6/site-packages/pymongo/helpers.py in _check_command_response(response, msg, allowable_errors, parse_write_concern_error)
#     153
#     154             msg = msg or "%s"
# --> 155             raise OperationFailure(msg % errmsg, code, response)
#     156
#     157
#
# OperationFailure: unknown top level operator: $provider_code_account

# %%
pymongo.IndexModel([("provider_code", pymongo.TEXT),
                                                  ("provider_account", pymongo.ASCENDING)],
                                                 name="provider_code_account")

# %% [markdown]
# #### Untagged resources

# %%
match_stage = {"$match": {"provider_code": "aws", "provider_account": {"$in": ["4565435"]}}}
application_stage = {"$match": {"context.application": {"$in": [[]]}}}
env_stage = {"$match": {"context.environment": {"$in": [[]]}}}
project_stage = {"$project": {"_id":0, "type": 1, "context": 1, "provider_resource_name": 1}}
# unwind_stage = {"$unwind": "$context.application"}
sort_stage = {"$sort": {"provider_resource_name": -1}}
limit_stage = {"$limit": 50}


groupby_stage = {"$group": {"_id": "$type", "sum": {"$sum": 1}}}
#cosmetic_output = {"$group": {"_id": "$_id.app", "data": {"$push": {"type": "$_id.type", "count": "$sum"}}}}
#rename_id = {"$project": {"_id": 0, "application": "$_id", "data": 1}}

# %%
import time
start_time = time.time()

pprint.pprint(list(inventory.aggregate([application_stage, groupby_stage], allowDiskUse=True)))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# [{'_id': 'independent_component', 'sum': 776},
#  {'_id': 'associated_component', 'sum': 143},
#  {'_id': 'service_instance', 'sum': 742}]
# --- 0.04167604446411133 seconds ---
